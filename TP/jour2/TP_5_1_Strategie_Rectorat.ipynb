# %% [markdown]
# # TP 5.1 — Stratégie data pour un rectorat (synthèse de groupe)**Durée indicative** : 1 h 30 — travail en groupes de 3 à 4 personnes.**Ressources** : `Docs/sources_data.md` section TP 5.1 (portails, IVAL, IPS, INSEE, Sirene, etc.).

# %% [markdown]
# ## 1. Cas d’usage prioritairesChoisir **deux** cas parmi :- Prévention du décrochage scolaire- Prévision démographique des effectifs par bassin- Pilotage de la mixité sociale- Optimisation de la carte des formations professionnelles- Suivi des indicateurs de valeur ajoutée| Cas 1 (titre) | Cas 2 (titre) ||---------------|---------------|| | |

# %% [markdown]
# ## 2. Pour chaque cas — sources et contraintes| Cas | Données nécessaires (internes / ouvertes) | Volumétrie estimée | Fréquence | Contraintes RGPD & mineurs ||-----|--------------------------------------------|--------------------|-----------|-----------------------------|| | | | | || | | | | |

# %% [markdown]
# ## 3. Architecture cible (schéma logique)Dessiner ou décrire : ingestion, stockage (lake / entrepôt), traitement (batch / streaming), restitution (BI, API). Tenir compte de la **doctrine cloud** de l’État (SecNumCloud pour données sensibles).*(Zone libre — schéma sur papier ou image importée dans une copie de ce notebook.)*

# %% [markdown]
# ## 4. Maquette de tableau de bordPublic cible : recteur, IA-DASEN, chef d’établissement, …Lister les indicateurs clés, la fréquence de mise à jour, et les **bonnes pratiques** de titres / accessibilité (RGAA).

# %% [markdown]
# ## 5. Risques et mitigation| Risque (technique / juridique / humain) | Mitigation ||----------------------------------------|------------|| | || | || | |Dimension **éthique** : décisions impliquant des mineurs, transparence algorithmique, complémentarité avec le jugement professionnel.

# %% [markdown]
# ## Restitution oralePrévoir **10 minutes** de présentation par groupe + 5 minutes de questions (voir énoncé du support de cours).
